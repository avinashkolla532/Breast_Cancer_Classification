# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashkolla532/Breast_Cancer_Classification/blob/main/Breast_Cancer_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()

# %%
cancer_data = pd.DataFrame(dataset.data , columns=dataset.feature_names)

# %%
cancer_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
cancer_data['result']=dataset.target

# %%
cancer_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_data.std()
# Out:
# mean radius                  3.524049
# mean texture                 4.301036
# mean perimeter              24.298981
# mean area                  351.914129
# mean smoothness              0.014064
# mean compactness             0.052813
# mean concavity               0.079720
# mean concave points          0.038803
# mean symmetry                0.027414
# mean fractal dimension       0.007060
# radius error                 0.277313
# texture error                0.551648
# perimeter error              2.021855
# area error                  45.491006
# smoothness error             0.003003
# compactness error            0.017908
# concavity error              0.030186
# concave points error         0.006170
# symmetry error               0.008266
# fractal dimension error      0.002646
# worst radius                 4.833242
# worst texture                6.146258
# worst perimeter             33.602542
# worst area                 569.356993
# worst smoothness             0.022832
# ...

# %%
standard = StandardScaler()

# %%
cancer_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
x = cancer_data.drop(columns='result',axis=1)
y = cancer_data['result']

# %%
print(x)

# %%
standard = StandardScaler()

# %%
cancer_data_standard = standard.fit_transform(cancer_data)

# %%
print(cancer_data_standard)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.75062224  1.93701461
#   -1.29767572]
#  [ 1.82982061 -0.35363241  1.68595471 ... -0.24388967  0.28118999
#   -1.29767572]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.152255    0.20139121
#   -1.29767572]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ... -1.10454895 -0.31840916
#   -1.29767572]
#  [ 1.83834103  2.33645719  1.98252415 ...  1.91908301  2.21963528
#   -1.29767572]
#  [-1.80840125  1.22179204 -1.81438851 ... -0.04813821 -0.75120669
#    0.77060855]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=3)

# %%
print(x.shape,x_test.shape,x_train.shape)
# Out:
# (569, 30) (114, 30) (455, 30)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction_train_x = model.predict(x_train)

# %%
accuracy = accuracy_score(prediction_train_x,y_train)

# %%
print(accuracy)
# Out:
# 0.9494505494505494

# %%
prediction_test_x = model.predict(x_test)
accuracy = accuracy_score(prediction_test_x,y_test)

# %%
print(accuracy)
# Out:
# 0.9473684210526315

# %%
input=(13.54,14.36,87.46,566.3,0.09779,0.08129,0.06664,0.04781,0.1885,0.05766,0.2699,0.7886,2.058,23.56,0.008462,0.0146,0.02387,0.01315,0.0198,0.0023,15.11,19.26,99.7,711.2,0.144,0.1773,0.239,0.1288,0.2977,0.07259)
input_to_array = np.asarray(input)
input_reshape = input_to_array.reshape(1,-1)
prediction = model.predict(input_reshape)

if(prediction==0):
  print("having no cancer")
else:
  print("having the cancer")
# Out:
# having the cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
